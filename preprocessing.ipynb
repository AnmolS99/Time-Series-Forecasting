# %%
import preprocessing
from scipy.stats.mstats import winsorize
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

df = preprocessing.load_dataset("datasets/no1_train.csv")

# %%
df.columns
# Out:
# Index(['start_time', 'hydro', 'micro', 'thermal', 'wind', 'river', 'total',
#        'y', 'sys_reg', 'flow'],
#       dtype='object')

# %%
y = df["y"]
upper_quantile = y.quantile(0.995)
lower_quantile = y.quantile(0.005)
df[df["y"] < lower_quantile]
# Out:
#                  start_time     hydro    micro  thermal     wind  river  \
# 33870   2019-05-07 04:40:00  1918.217  304.270     22.1  128.213    0.0
# 33871   2019-05-07 04:45:00  1918.217  304.270     22.1  128.213    0.0
# 33872   2019-05-07 04:50:00  1918.217  304.270     22.1  128.213    0.0
# 33873   2019-05-07 04:55:00  1918.217  304.270     22.1  128.213    0.0
# 37636   2019-05-20 06:30:00  2419.110  296.407     19.6   33.554    0.0
# ...                     ...       ...      ...      ...      ...    ...
# 209685  2021-01-06 15:55:00  2528.306  279.081     23.6   14.267    0.0
# 209686  2021-01-06 16:00:00  2532.779  279.241     23.6   13.823    0.0
# 209687  2021-01-06 16:05:00  2532.779  279.241     23.6   13.823    0.0
# 209688  2021-01-06 16:10:00  2532.779  279.241     23.6   13.823    0.0
# 222267  2021-02-19 08:25:00  2132.390  154.570     22.1    7.140    0.0
#
#            total            y  sys_reg     flow
# 33870   2372.800  -812.904465      0.0 -1652.40
# ...

# %%
y = df["y"]
clipped = winsorize(y, limits=[0.005, 0.005])
df["y"] = np.array(clipped)
df[df["y"] < lower_quantile]
# Out:
#                  start_time     hydro    micro  thermal     wind  river  \
# 33870   2019-05-07 04:40:00  1918.217  304.270     22.1  128.213    0.0
# 33871   2019-05-07 04:45:00  1918.217  304.270     22.1  128.213    0.0
# 33872   2019-05-07 04:50:00  1918.217  304.270     22.1  128.213    0.0
# 33873   2019-05-07 04:55:00  1918.217  304.270     22.1  128.213    0.0
# 37636   2019-05-20 06:30:00  2419.110  296.407     19.6   33.554    0.0
# ...                     ...       ...      ...      ...      ...    ...
# 209685  2021-01-06 15:55:00  2528.306  279.081     23.6   14.267    0.0
# 209686  2021-01-06 16:00:00  2532.779  279.241     23.6   13.823    0.0
# 209687  2021-01-06 16:05:00  2532.779  279.241     23.6   13.823    0.0
# 209688  2021-01-06 16:10:00  2532.779  279.241     23.6   13.823    0.0
# 222267  2021-02-19 08:25:00  2132.390  154.570     22.1    7.140    0.0
#
#            total           y  sys_reg     flow
# 33870   2372.800 -802.506585      0.0 -1652.40
# ...

# %%
df.columns
# Out:
# Index(['start_time', 'hydro', 'micro', 'thermal', 'wind', 'river', 'total',
#        'y', 'sys_reg', 'flow'],
#       dtype='object')

# %%
df2 = df[["hydro", "micro", "thermal", "wind", "river", "total", "y", "sys_reg", "flow"]]
df2
# Out:
#            hydro    micro  thermal     wind  river     total           y  \
# 0       1591.839  141.928     11.5   74.428    0.0  1819.695  341.330021
# 1       1591.839  141.928     11.5   74.428    0.0  1819.695  330.114330
# 2       1591.839  141.928     11.5   74.428    0.0  1819.695  323.877221
# 3       1591.839  141.928     11.5   74.428    0.0  1819.695  296.438463
# 4       1591.839  141.928     11.5   74.428    0.0  1819.695  269.097132
# ...          ...      ...      ...      ...    ...       ...         ...
# 225083  1942.486  191.881     20.1  106.431    0.0  2266.098  141.618915
# 225084  1942.486  191.881     20.1  106.431    0.0  2266.098  129.043820
# 225085  1942.486  191.881     20.1  106.431    0.0  2266.098   94.907548
# 225086  1942.486  191.881     20.1  106.431    0.0  2266.098  102.589040
# 225087  1942.486  191.881     20.1  106.431    0.0  2266.098   73.829019
#
#         sys_reg    flow
# 0          10.0 -4417.4
# 1          10.0 -4417.4
# ...

# %%
scaler = MinMaxScaler()
scale_features = df[["hydro", "micro", "thermal", "wind", "river", "total", "y", "sys_reg", "flow"]]
df[["hydro", "micro", "thermal", "wind", "river", "total", "y", "sys_reg", "flow"]] = scaler.fit_transform(scale_features)
df
# Out:
#                  start_time     hydro     micro   thermal      wind  river  \
# 0       2019-01-09 14:10:00  0.392892  0.228922  0.447471  0.422886    0.0
# 1       2019-01-09 14:15:00  0.392892  0.228922  0.447471  0.422886    0.0
# 2       2019-01-09 14:20:00  0.392892  0.228922  0.447471  0.422886    0.0
# 3       2019-01-09 14:25:00  0.392892  0.228922  0.447471  0.422886    0.0
# 4       2019-01-09 14:30:00  0.392892  0.228922  0.447471  0.422886    0.0
# ...                     ...       ...       ...       ...       ...    ...
# 225083  2021-03-01 03:05:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225084  2021-03-01 03:10:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225085  2021-03-01 03:15:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225086  2021-03-01 03:20:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225087  2021-03-01 03:25:00  0.544551  0.414689  0.782101  0.604722    0.0
#
#            total         y   sys_reg      flow
# ...

# %%
date_time = pd.to_datetime(df["start_time"])
df["time_of_day_sin"] = np.sin(date_time.dt.hour * ((2 * np.pi) / 24))
df["time_of_day_cos"] = np.cos(date_time.dt.hour * ((2 * np.pi) / 24))

df["time_of_week_sin"] = np.sin(date_time.dt.day_of_week * ((2 * np.pi) / 7))
df["time_of_week_cos"] = np.cos(date_time.dt.day_of_week * ((2 * np.pi) / 7))

df["time_of_year_sin"] = np.sin(date_time.dt.month * ((2 * np.pi) / 12))
df["time_of_year_cos"] = np.cos(date_time.dt.month * ((2 * np.pi) / 12))

df
# Out:
#                  start_time     hydro     micro   thermal      wind  river  \
# 0       2019-01-09 14:10:00  0.392892  0.228922  0.447471  0.422886    0.0
# 1       2019-01-09 14:15:00  0.392892  0.228922  0.447471  0.422886    0.0
# 2       2019-01-09 14:20:00  0.392892  0.228922  0.447471  0.422886    0.0
# 3       2019-01-09 14:25:00  0.392892  0.228922  0.447471  0.422886    0.0
# 4       2019-01-09 14:30:00  0.392892  0.228922  0.447471  0.422886    0.0
# ...                     ...       ...       ...       ...       ...    ...
# 225083  2021-03-01 03:05:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225084  2021-03-01 03:10:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225085  2021-03-01 03:15:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225086  2021-03-01 03:20:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225087  2021-03-01 03:25:00  0.544551  0.414689  0.782101  0.604722    0.0
#
#            total         y   sys_reg      flow  time_of_day_sin  \
# ...

# %%
date_time1 = pd.to_datetime("2021-03-01 03:25:00")
date_time2 = pd.to_datetime("2021-02-28 03:25:00")
one_day_timesteps = (1*24*60) // 5
df["y_24h"] = df["y"].shift(one_day_timesteps)
df[["start_time", "y", "y_24h"]]

df.loc[df["start_time"] == str(date_time1)][["start_time", "y", "y_24h"]]
# Out:
#                  start_time         y     y_24h
# 225087  2021-03-01 03:25:00  0.344027  0.336026

# %%
df["prev_y"] = df["y"].shift(1)
df
# Out:
#                  start_time     hydro     micro   thermal      wind  river  \
# 0       2019-01-09 14:10:00  0.392892  0.228922  0.447471  0.422886    0.0
# 1       2019-01-09 14:15:00  0.392892  0.228922  0.447471  0.422886    0.0
# 2       2019-01-09 14:20:00  0.392892  0.228922  0.447471  0.422886    0.0
# 3       2019-01-09 14:25:00  0.392892  0.228922  0.447471  0.422886    0.0
# 4       2019-01-09 14:30:00  0.392892  0.228922  0.447471  0.422886    0.0
# ...                     ...       ...       ...       ...       ...    ...
# 225083  2021-03-01 03:05:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225084  2021-03-01 03:10:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225085  2021-03-01 03:15:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225086  2021-03-01 03:20:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225087  2021-03-01 03:25:00  0.544551  0.414689  0.782101  0.604722    0.0
#
#            total         y   sys_reg      flow  time_of_day_sin  \
# ...

# %%
df['start_time'] = pd.to_datetime(df['start_time'])
df = pd.merge_asof(
    df,
    df.resample('D', on="start_time")["y"].mean().shift(1),
    right_index=True,
    left_on="start_time",
)
df = df.rename(columns={"y_x": "y", "y_y": "y_yesterday"})
df
# Out:
#                 start_time     hydro     micro   thermal      wind  river  \
# 0      2019-01-09 14:10:00  0.392892  0.228922  0.447471  0.422886    0.0
# 1      2019-01-09 14:15:00  0.392892  0.228922  0.447471  0.422886    0.0
# 2      2019-01-09 14:20:00  0.392892  0.228922  0.447471  0.422886    0.0
# 3      2019-01-09 14:25:00  0.392892  0.228922  0.447471  0.422886    0.0
# 4      2019-01-09 14:30:00  0.392892  0.228922  0.447471  0.422886    0.0
# ...                    ...       ...       ...       ...       ...    ...
# 225083 2021-03-01 03:05:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225084 2021-03-01 03:10:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225085 2021-03-01 03:15:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225086 2021-03-01 03:20:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225087 2021-03-01 03:25:00  0.544551  0.414689  0.782101  0.604722    0.0
#
#            total         y   sys_reg      flow  time_of_day_sin  \
# ...

# %%
# Testing that y_yesterday is correct, by checking what the average was for 2021-02-28
mask = (df['start_time'] >= '2021-02-28') & (df['start_time'] < '2021-03-01')
a = df.loc[mask]
print(a["y"].mean())
df
# Out:
# 0.41082950576389354
#                 start_time     hydro     micro   thermal      wind  river  \
# 0      2019-01-09 14:10:00  0.392892  0.228922  0.447471  0.422886    0.0
# 1      2019-01-09 14:15:00  0.392892  0.228922  0.447471  0.422886    0.0
# 2      2019-01-09 14:20:00  0.392892  0.228922  0.447471  0.422886    0.0
# 3      2019-01-09 14:25:00  0.392892  0.228922  0.447471  0.422886    0.0
# 4      2019-01-09 14:30:00  0.392892  0.228922  0.447471  0.422886    0.0
# ...                    ...       ...       ...       ...       ...    ...
# 225083 2021-03-01 03:05:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225084 2021-03-01 03:10:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225085 2021-03-01 03:15:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225086 2021-03-01 03:20:00  0.544551  0.414689  0.782101  0.604722    0.0
# 225087 2021-03-01 03:25:00  0.544551  0.414689  0.782101  0.604722    0.0
#
# ...
